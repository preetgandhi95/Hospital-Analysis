# %%
import pandas as pd
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings("ignore")
bs08 = pd.read_csv('DE1_0_2008_Beneficiary_Summary_File_Sample_4.csv')
bs09 = pd.read_csv('DE1_0_2009_Beneficiary_Summary_File_Sample_4.csv')
bs10 = pd.read_csv('DE1_0_2010_Beneficiary_Summary_File_Sample_4.csv')
bs = pd.concat([bs08, bs09, bs10])
bs.describe().transpose()
# Out:
#                              count          mean            std         min  \
# BENE_BIRTH_DT             343506.0  1.936387e+07  125155.780608  19090101.0
# BENE_DEATH_DT               5385.0  2.009075e+07    8135.080051  20080101.0
# BENE_SEX_IDENT_CD         343506.0  1.557725e+00       0.496657         1.0
# BENE_RACE_CD              343506.0  1.280615e+00       0.748403         1.0
# SP_STATE_CODE             343506.0  2.575140e+01      15.600282         1.0
# BENE_COUNTY_CD            343506.0  3.656617e+02     266.584105         0.0
# BENE_HI_CVRAGE_TOT_MONS   343506.0  1.118686e+01       2.888467         0.0
# BENE_SMI_CVRAGE_TOT_MONS  343506.0  1.084080e+01       3.413547         0.0
# BENE_HMO_CVRAGE_TOT_MONS  343506.0  3.162664e+00       5.190276         0.0
# PLAN_CVRG_MOS_NUM         343506.0  8.529400e+00       5.193562         0.0
# SP_ALZHDMTA               343506.0  1.802530e+00       0.398090         1.0
# ...

# %%
for key in bs:
    print(key, bs[key].unique().shape)
# Out:
# DESYNPUF_ID (116279,)
# BENE_BIRTH_DT (900,)
# BENE_DEATH_DT (37,)
# BENE_SEX_IDENT_CD (2,)
# BENE_RACE_CD (4,)
# BENE_ESRD_IND (2,)
# SP_STATE_CODE (52,)
# BENE_COUNTY_CD (313,)
# BENE_HI_CVRAGE_TOT_MONS (13,)
# BENE_SMI_CVRAGE_TOT_MONS (13,)
# BENE_HMO_CVRAGE_TOT_MONS (13,)
# PLAN_CVRG_MOS_NUM (13,)
# SP_ALZHDMTA (2,)
# SP_CHF (2,)
# SP_CHRNKIDN (2,)
# SP_CNCR (2,)
# SP_COPD (2,)
# SP_DEPRESSN (2,)
# SP_DIABETES (2,)
# SP_ISCHMCHT (2,)
# SP_OSTEOPRS (2,)
# SP_RA_OA (2,)
# SP_STRKETIA (2,)
# MEDREIMB_IP (3192,)
# BENRES_IP (323,)
# PPPYMT_IP (81,)
# MEDREIMB_OP (2076,)
# BENRES_OP (798,)
# PPPYMT_OP (121,)
# MEDREIMB_CAR (1320,)
# BENRES_CAR (397,)
# PPPYMT_CAR (164,)

# %%
bs.isnull
# Out:
# <bound method NDFrame.isnull of              DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0       0000D684F621DFBD       19380901            NaN                  2
# 1       0000FC926C37BC5F       19210901            NaN                  1
# 2       00011C5F15219ACD       19280101            NaN                  2
# 3       0001694E47AE68F9       19410201            NaN                  1
# 4       0001956E385E312B       19250601            NaN                  1
# 5       0002056B40CEE448       19201001            NaN                  2
# 6       000221DA56466406       19400601            NaN                  2
# 7       00029C892541E3B7       19330701            NaN                  1
# 8       0002AF38C8CE0E20       19421101            NaN                  1
# 9       0004D03F1BD5E607       19430701            NaN                  1
# 10      00052CF30906F215       19130501            NaN                  2
# ...

# %%
l=['BENE_RACE_CD','SP_STATE_CODE','BENE_SEX_IDENT_CD','SP_ALZHDMTA','SP_CHF','SP_CHRNKIDN','SP_CNCR','SP_COPD','SP_DEPRESSN','SP_DIABETES','SP_ISCHMCHT','SP_OSTEOPRS']
for x in l:
    plt.figure()
    hist_inc = bs[x].hist()
    plt.title('Distribution of ' +x)
    plt.show()

# %%
incl = pd.read_csv('DE1_0_2008_to_2010_Inpatient_Claims_Sample_4.csv')
incl.describe().transpose()
# Out:
#                                   count          mean           std  \
# CLM_ID                          66253.0  7.445007e+14  2.869226e+11
# SEGMENT                         66253.0  1.000815e+00  2.853779e-02
# CLM_FROM_DT                     66199.0  2.008842e+07  7.585606e+03
# CLM_THRU_DT                     66199.0  2.008857e+07  7.558648e+03
# CLM_PMT_AMT                     66253.0  9.584703e+03  9.261137e+03
# NCH_PRMRY_PYR_CLM_PD_AMT        66253.0  4.491963e+02  4.033499e+03
# AT_PHYSN_NPI                    65610.0  5.060034e+09  2.925321e+09
# OP_PHYSN_NPI                    38593.0  5.080403e+09  2.897728e+09
# OT_PHYSN_NPI                     7587.0  5.029096e+09  2.877354e+09
# CLM_ADMSN_DT                    66253.0  2.008842e+07  7.584726e+03
# CLM_PASS_THRU_PER_DIEM_AMT      66253.0  2.952908e+01  7.600172e+01
# NCH_BENE_IP_DDCTBL_AMT          64189.0  1.056826e+03  2.966489e+01
# NCH_BENE_PTA_COINSRNC_LBLTY_AM  66253.0  8.865863e+01  1.056446e+03
# ...

# %%
for key in incl:
    print(key, incl[key].unique().shape)
# Out:
# DESYNPUF_ID (37715,)
# CLM_ID (66199,)
# SEGMENT (2,)
# CLM_FROM_DT (1118,)
# CLM_THRU_DT (1097,)
# PRVDR_NUM (2695,)
# CLM_PMT_AMT (92,)
# NCH_PRMRY_PYR_CLM_PD_AMT (75,)
# AT_PHYSN_NPI (16816,)
# OP_PHYSN_NPI (12054,)
# OT_PHYSN_NPI (4399,)
# CLM_ADMSN_DT (1117,)
# ADMTNG_ICD9_DGNS_CD (2297,)
# CLM_PASS_THRU_PER_DIEM_AMT (15,)
# NCH_BENE_IP_DDCTBL_AMT (4,)
# NCH_BENE_PTA_COINSRNC_LBLTY_AM (37,)
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM (18,)
# CLM_UTLZTN_DAY_CNT (91,)
# NCH_BENE_DSCHRG_DT (1096,)
# CLM_DRG_CD (740,)
# ICD9_DGNS_CD_1 (2719,)
# ICD9_DGNS_CD_2 (2925,)
# ICD9_DGNS_CD_3 (2862,)
# ICD9_DGNS_CD_4 (2880,)
# ICD9_DGNS_CD_5 (2910,)
# ICD9_DGNS_CD_6 (2843,)
# ICD9_DGNS_CD_7 (2760,)
# ICD9_DGNS_CD_8 (2728,)
# ICD9_DGNS_CD_9 (2609,)
# ICD9_DGNS_CD_10 (1120,)
# ICD9_PRCDR_CD_1 (1295,)
# ICD9_PRCDR_CD_2 (1992,)
# ICD9_PRCDR_CD_3 (1665,)
# ICD9_PRCDR_CD_4 (1387,)
# ICD9_PRCDR_CD_5 (1157,)
# ICD9_PRCDR_CD_6 (953,)
# HCPCS_CD_1 (1,)
# HCPCS_CD_2 (1,)
# HCPCS_CD_3 (1,)
# HCPCS_CD_4 (1,)
# ...

# %%
incl.isnull
# Out:
# <bound method NDFrame.isnull of             DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0      0002056B40CEE448  744651196200598        1   20090208.0   20090210.0
# 1      0004D03F1BD5E607  744871196246937        1   20090302.0   20090313.0
# 2      0004D03F1BD5E607  744861196237234        1   20100807.0   20100810.0
# 3      00058FD68952AEA3  744391196252740        1   20091216.0   20091217.0
# 4      000A69B545F952D2  744621196258271        1   20090518.0   20090521.0
# 5      000AA8441A4F1E1D  744411196227543        1   20100307.0   20100313.0
# 6      000AEDDB6F34EBE5  744871196239801        1   20080121.0   20080128.0
# 7      000B61BC33CC145F  744951196231659        1   20080729.0   20080804.0
# 8      000B61BC33CC145F  744601196238256        1   20090131.0   20090208.0
# 9      000D21E99A39864E  744131196231877        1   20091118.0   20091120.0
# 10     000D21E99A39864E  744741196202369        1   20091211.0   20091220.0
# ...

# %%
outcl = pd.read_csv('DE1_0_2008_to_2010_Outpatient_Claims_Sample_4.csv') 
outcl.describe().transpose()
# Out:
#                                    count          mean           std  \
# CLM_ID                          789485.0  9.050216e+13  2.856982e+11
# SEGMENT                         789485.0  1.014216e+00  1.183788e-01
# CLM_FROM_DT                     778262.0  2.008922e+07  7.475377e+03
# CLM_THRU_DT                     778262.0  2.008926e+07  7.471984e+03
# CLM_PMT_AMT                     789485.0  2.830684e+02  5.693987e+02
# NCH_PRMRY_PYR_CLM_PD_AMT        789485.0  1.028386e+01  2.375598e+02
# AT_PHYSN_NPI                    771907.0  4.969920e+09  2.874539e+09
# OP_PHYSN_NPI                    133799.0  4.928026e+09  2.886523e+09
# OT_PHYSN_NPI                    256396.0  4.903251e+09  2.888922e+09
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM  789485.0  1.329981e-02  2.493807e+00
# ICD9_PRCDR_CD_1                    193.0  6.356269e+03  3.223177e+03
# NCH_BENE_PTB_DDCTBL_AMT         789485.0  2.823436e+00  1.556001e+01
# NCH_BENE_PTB_COINSRNC_AMT       789485.0  8.389695e+01  1.791145e+02
# ...

# %%
for key in outcl:
    print(key, outcl[key].unique().shape)
# Out:
# DESYNPUF_ID (85172,)
# CLM_ID (778472,)
# SEGMENT (2,)
# CLM_FROM_DT (1117,)
# CLM_THRU_DT (1097,)
# PRVDR_NUM (6293,)
# CLM_PMT_AMT (53,)
# NCH_PRMRY_PYR_CLM_PD_AMT (33,)
# AT_PHYSN_NPI (98594,)
# OP_PHYSN_NPI (39360,)
# OT_PHYSN_NPI (56467,)
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM (8,)
# ICD9_DGNS_CD_1 (11156,)
# ICD9_DGNS_CD_2 (5642,)
# ICD9_DGNS_CD_3 (5042,)
# ICD9_DGNS_CD_4 (4484,)
# ICD9_DGNS_CD_5 (3904,)
# ICD9_DGNS_CD_6 (3445,)
# ICD9_DGNS_CD_7 (3035,)
# ICD9_DGNS_CD_8 (2706,)
# ICD9_DGNS_CD_9 (2378,)
# ICD9_DGNS_CD_10 (621,)
# ICD9_PRCDR_CD_1 (100,)
# ICD9_PRCDR_CD_2 (88,)
# ICD9_PRCDR_CD_3 (50,)
# ICD9_PRCDR_CD_4 (34,)
# ICD9_PRCDR_CD_5 (27,)
# ICD9_PRCDR_CD_6 (20,)
# NCH_BENE_PTB_DDCTBL_AMT (12,)
# NCH_BENE_PTB_COINSRNC_AMT (21,)
# ADMTNG_ICD9_DGNS_CD (4403,)
# HCPCS_CD_1 (2521,)
# HCPCS_CD_2 (3396,)
# HCPCS_CD_3 (3273,)
# HCPCS_CD_4 (3179,)
# HCPCS_CD_5 (3000,)
# HCPCS_CD_6 (2980,)
# HCPCS_CD_7 (2754,)
# HCPCS_CD_8 (2633,)
# HCPCS_CD_9 (2536,)
# HCPCS_CD_10 (2451,)
# ...

# %%
outcl.isnull
# Out:
# <bound method NDFrame.isnull of              DESYNPUF_ID          CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0       0000D684F621DFBD  90252200077052        1   20081026.0   20081026.0
# 1       0000D684F621DFBD  90352200718632        1   20081122.0   20081122.0
# 2       0000D684F621DFBD  90132200393557        1   20090127.0   20090127.0
# 3       0000D684F621DFBD  90082200462102        1   20090530.0   20090530.0
# 4       0000D684F621DFBD  90122200676942        1   20090630.0   20090630.0
# 5       0000D684F621DFBD  90872200490997        1   20090827.0   20090827.0
# 6       0000D684F621DFBD  90912200553165        1   20090914.0   20090914.0
# 7       0000D684F621DFBD  90602200527233        1   20091126.0   20091126.0
# 8       0000D684F621DFBD  90842200569387        1   20091219.0   20091219.0
# 9       00011C5F15219ACD  90372200660163        1   20090902.0   20090902.0
# 10      0001694E47AE68F9  90672200191887        1   20080510.0   20080510.0
# ...

# %%
pde = pd.read_csv('DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_4.csv')
pde.describe()
# Out:
#              PDE_ID       SRVC_DT  QTY_DSPNSD_NUM  DAYS_SUPLY_NUM  \
# count  5.549070e+06  5.549070e+06    5.549070e+06    5.549070e+06
# mean   7.825044e+14  2.008955e+07    5.114568e+01    3.418199e+01
# std    2.857150e+11  7.675093e+03    5.181602e+01    2.124135e+01
# min    7.820144e+14  2.008010e+07    0.000000e+00    0.000000e+00
# 25%    7.822544e+14  2.008092e+07    3.000000e+01    3.000000e+01
# 50%    7.825044e+14  2.009051e+07    3.000000e+01    3.000000e+01
# 75%    7.827544e+14  2.009123e+07    6.000000e+01    3.000000e+01
# max    7.829944e+14  2.010123e+07    3.600000e+02    9.000000e+01
#
#        PTNT_PAY_AMT  TOT_RX_CST_AMT
# count  5.549070e+06    5.549070e+06
# mean   1.032169e+01    6.133008e+01
# std    2.416456e+01    9.415282e+01
# min    0.000000e+00    0.000000e+00
# 25%    0.000000e+00    1.000000e+01
# 50%    0.000000e+00    2.000000e+01
# 75%    1.000000e+01    8.000000e+01
# max    1.700000e+02    5.700000e+02

# %%
for key in pde:
    print(key, pde[key].unique().shape)
# Out:
# DESYNPUF_ID (99597,)
# PDE_ID (5549070,)
# SRVC_DT (1096,)
# PROD_SRVC_ID (480822,)
# QTY_DSPNSD_NUM (37,)
# DAYS_SUPLY_NUM (10,)
# PTNT_PAY_AMT (18,)
# TOT_RX_CST_AMT (58,)

# %%
pde.isnull
# Out:
# <bound method NDFrame.isnull of               DESYNPUF_ID           PDE_ID   SRVC_DT PROD_SRVC_ID  \
# 0        0000D684F621DFBD  782324410276735  20101207  68382012817
# 1        0000FC926C37BC5F  782094410970244  20080902    339635011
# 2        0000FC926C37BC5F  782834408711765  20081004  49884064074
# 3        0000FC926C37BC5F  782704409726579  20081021  58016035305
# 4        0000FC926C37BC5F  782584408645636  20081026  10147060302
# 5        0000FC926C37BC5F  782564409086248  20090106     28010901
# 6        0000FC926C37BC5F  782464412720050  20090222  58016013502
# 7        0000FC926C37BC5F  782924412042315  20090402  16590015214
# 8        0000FC926C37BC5F  782714408701249  20090512  49348079734
# 9        0000FC926C37BC5F  782514410980328  20090524  49288039804
# 10       00011C5F15219ACD  782414411077713  20080117  50111047702
# 11       00011C5F15219ACD  782794407989584  20080118    814026140
# 12       00011C5F15219ACD  782474413424365  20080129  48695114401
# ...

# %%
cca = pd.read_csv('DE1_0_2008_to_2010_Carrier_Claims_Sample_4A.csv')
ccb = pd.read_csv('DE1_0_2008_to_2010_Carrier_Claims_Sample_4B.csv')
cc = pd.concat([cca, ccb])
cc.shape
# Out:
# (4743079, 142)

# %%
#Total patients
n = cc['DESYNPUF_ID'].unique()
len(n)
# Out:
# 98538

# %%
cc.head(5)
# Out:
#         DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT ICD9_DGNS_CD_1  \
# 0  0000D684F621DFBD  436363306632611     20080403     20080403           7201
# 1  0000D684F621DFBD  436833303960959     20080416     20080416          36524
# 2  0000D684F621DFBD  436233307810606     20080419     20080419          70401
# 3  0000D684F621DFBD  436373306449501     20080705     20080705          36563
# 4  0000D684F621DFBD  436393308320044     20080708     20080708          36501
#
#   ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2           7020            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
#Earliest claim date
cc['CLM_FROM_DT'].min()
# Out:
# 20080101

# %%
#Latest claim date
cc['CLM_FROM_DT'].max()
# Out:
# 20101231

# %%
cc.describe().transpose()
# Out:
#                                    count          mean           std  \
# CLM_ID                         4743079.0  4.365032e+14  2.857052e+11
# CLM_FROM_DT                    4743079.0  2.008947e+07  7.639669e+03
# CLM_THRU_DT                    4743079.0  2.008948e+07  7.640083e+03
# PRF_PHYSN_NPI_1                4734117.0  4.952118e+09  2.896042e+09
# PRF_PHYSN_NPI_2                2085943.0  4.950544e+09  2.896335e+09
# PRF_PHYSN_NPI_3                1040984.0  4.952068e+09  2.896421e+09
# PRF_PHYSN_NPI_4                 582735.0  4.946075e+09  2.895645e+09
# PRF_PHYSN_NPI_5                 353514.0  4.945963e+09  2.895826e+09
# PRF_PHYSN_NPI_6                 223507.0  4.952803e+09  2.896084e+09
# PRF_PHYSN_NPI_7                 120555.0  4.957072e+09  2.896862e+09
# PRF_PHYSN_NPI_8                  80732.0  4.966715e+09  2.897364e+09
# PRF_PHYSN_NPI_9                  55355.0  4.967362e+09  2.895229e+09
# PRF_PHYSN_NPI_10                 39200.0  4.957362e+09  2.894723e+09
# ...

# %%
for key in cc:
    print(key, cc[key].unique().shape)
# Out:
# DESYNPUF_ID (98538,)
# CLM_ID (4743079,)
# CLM_FROM_DT (1096,)
# CLM_THRU_DT (1096,)
# ICD9_DGNS_CD_1 (12648,)
# ICD9_DGNS_CD_2 (8586,)
# ICD9_DGNS_CD_3 (7826,)
# ICD9_DGNS_CD_4 (7069,)
# ICD9_DGNS_CD_5 (4330,)
# ICD9_DGNS_CD_6 (3756,)
# ICD9_DGNS_CD_7 (3557,)
# ICD9_DGNS_CD_8 (3233,)
# PRF_PHYSN_NPI_1 (615353,)
# PRF_PHYSN_NPI_2 (478286,)
# PRF_PHYSN_NPI_3 (355843,)
# PRF_PHYSN_NPI_4 (260861,)
# PRF_PHYSN_NPI_5 (190219,)
# PRF_PHYSN_NPI_6 (137127,)
# PRF_PHYSN_NPI_7 (83857,)
# PRF_PHYSN_NPI_8 (59634,)
# PRF_PHYSN_NPI_9 (42710,)
# PRF_PHYSN_NPI_10 (31120,)
# PRF_PHYSN_NPI_11 (22200,)
# PRF_PHYSN_NPI_12 (16889,)
# PRF_PHYSN_NPI_13 (12100,)
# TAX_NUM_1 (232710,)
# TAX_NUM_2 (191279,)
# TAX_NUM_3 (151584,)
# TAX_NUM_4 (118367,)
# TAX_NUM_5 (92206,)
# TAX_NUM_6 (71195,)
# TAX_NUM_7 (48118,)
# TAX_NUM_8 (36498,)
# TAX_NUM_9 (27790,)
# TAX_NUM_10 (21356,)
# TAX_NUM_11 (16048,)
# TAX_NUM_12 (12774,)
# TAX_NUM_13 (9599,)
# HCPCS_CD_1 (6737,)
# HCPCS_CD_2 (6307,)
# HCPCS_CD_3 (5322,)
# ...

# %%
cc.isnull
# Out:
# <bound method NDFrame.isnull of               DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT  \
# 0        0000D684F621DFBD  436363306632611     20080403     20080403
# 1        0000D684F621DFBD  436833303960959     20080416     20080416
# 2        0000D684F621DFBD  436233307810606     20080419     20080419
# 3        0000D684F621DFBD  436373306449501     20080705     20080705
# 4        0000D684F621DFBD  436393308320044     20080708     20080708
# 5        0000D684F621DFBD  436713307010540     20080802     20080802
# 6        0000D684F621DFBD  436683305475431     20080808     20080808
# 7        0000D684F621DFBD  436643305576599     20080813     20080813
# 8        0000D684F621DFBD  436263307345081     20080824     20080824
# 9        0000D684F621DFBD  436753304676502     20080910     20080910
# 10       0000D684F621DFBD  436093307130784     20081105     20081105
# 11       0000D684F621DFBD  436463308123591     20081122     20081122
# ...
